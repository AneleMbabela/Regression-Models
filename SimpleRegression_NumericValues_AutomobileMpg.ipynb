# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
automobile_df = pd.read_csv('datasets/auto-mpg-processed.csv')

automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 27   18.0          3          70.0          90    2124          13.5   47
# 130  24.0          6         200.0          81    3012          17.6   44
# 229  25.0          4         110.0          87    2672          17.5   50
# 66   15.5          8         400.0         190    4325          12.2   43
# 183  26.0          4          97.0          75    2265          18.2   43

# %%
from sklearn.model_selection import train_test_split

X = automobile_df[['horsepower']]
Y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.sample(5)
# Out:
#      horsepower
# 322          70
# 371         140
# 168          88
# 388         110
# 97           88

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print('Training score: ', linear_model.score(x_train, y_train))
# Out:
# Training score:  0.613661332835701

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print('Testing score: ', r2_score(y_test, y_pred))
# Out:
# Testing score:  0.57445821807309

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Horsepower')
plt.ylabel('Mpg')
plt.show()

# %%
X = automobile_df[['age']]
Y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

print('Training score: ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)

print('Testing score: ', r2_score(y_test, y_pred))
# Out:
# Training score:  0.32444709389743775
# Testing score:  0.39284460037165203

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Age')
plt.ylabel('Mpg')
plt.show()

# %%
X = automobile_df[['displacement', 'horsepower', 'weight']]
Y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print('Training score: ', linear_model.score(x_train, y_train))
# Out:
# Training score:  0.7284813532607644

# %%
predictors = x_train.columns
coef = pd.Series(linear_model.coef_, predictors).sort_values()

print(coef)
# Out:
# horsepower     -0.039947
# displacement   -0.008019
# weight         -0.005420
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

# %%
print('Testing score: ', r2_score(y_test, y_pred))
# Out:
# Testing score:  0.5711337799575474

# %%
plt.figure(figsize = (20,10))

plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')

plt.ylabel('Mpg')

plt.legend()
plt.show()

# %%
X = automobile_df[['displacement', 'horsepower', 'weight', 'acceleration', 'cylinders']]
Y = automobile_df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print('Training score: ', linear_model.score(x_train, y_train))
# Out:
# Training score:  0.710860217947598

# %%
predictors = x_train.columns
coef = pd.Series(linear_model.coef_, predictors).sort_values()

print(coef)
# Out:
# cylinders      -0.347519
# horsepower     -0.051587
# acceleration   -0.030820
# weight         -0.005160
# displacement    0.000464
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

# %%
print('Testing score: ', r2_score(y_test, y_pred))
# Out:
# Testing score:  0.6931780095986426

# %%
plt.figure(figsize = (20,10))

plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')

plt.ylabel('Mpg')

plt.legend()
plt.show()
